# %% [markdown]
# <a href="https://colab.research.google.com/github/vrhughes/DS3001Group/blob/development/VH_Data_kaggle1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# let's clone some stuff
! git clone https://github.com/vrhughes/DS3001Group
# Out:
# Cloning into 'DS3001Group'...
# remote: Enumerating objects: 108, done.
# remote: Counting objects: 100% (108/108), done.
# remote: Compressing objects: 100% (100/100), done.
# remote: Total 108 (delta 33), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (108/108), 1.43 MiB | 7.55 MiB/s, done.
# Resolving deltas: 100% (33/33), done.

# %%
# import all the things
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# let's get the data
data = pd.read_csv('https://raw.githubusercontent.com/vrhughes/DS3001Group/main/Data/kaggle1.csv')

# let's see the data :)
display(data)

# drop stupid columns
data = data.drop(['date', 'hour', 'left channel team1', 'left channel team2', 'left inside channel team1', 'left inside channel team2', 'central channel team1', 'central channel team2', 'right inside channel team1', 'right inside channel team2', 'right channel team1', 'right channel team2'], axis=1)

# let's drop some more
data = data.drop(['total offers to receive team1', 'total offers to receive team2', 'inbehind offers to receive team1', 'inbehind offers to receive team2', 'inbetween offers to receive team1', 'inbetween offers to receive team2', 'infront offers to receive team1', 'infront offers to receive team2', 'receptions between midfield and defensive lines team1', 'receptions between midfield and defensive lines team2', 'attempted line breaks team1', 'attempted line breaks team2', 'completed line breaksteam1', 'completed line breaks team2', 'attempted defensive line breaks team1', 'attempted defensive line breaks team2', 'switches of play completed team1', 'switches of play completed team2'], axis=1)

# let's see the data again
display(data)
# Out:
#             team1         team2 possession team1 possession team2  \
# 0           QATAR       ECUADOR              42%              50%
# 1         ENGLAND          IRAN              72%              19%
# 2         SENEGAL   NETHERLANDS              44%              45%
# 3   UNITED STATES         WALES              51%              39%
# 4       ARGENTINA  SAUDI ARABIA              64%              24%
# ..            ...           ...              ...              ...
# 59        ENGLAND        FRANCE              54%              36%
# 60      ARGENTINA       CROATIA              34%              54%
# 61         FRANCE       MOROCCO              34%              55%
# 62        CROATIA       MOROCCO              45%              45%
# 63      ARGENTINA        FRANCE              46%              40%
#
#    possession in contest  number of goals team1  number of goals team2  \
# 0                     8%                      0                      2
# ...

# %% [markdown]
# Now that we cleared away a ton of the irrelevant data we have a clearer view and can ask some questions.

# %%
# a list of booleans which tells us if the team with more possession is the team
# that won
more_possession_wins = []
for index, row in data.iterrows():
  if row['possession team1'] > row['possession team2'] and row['number of goals team1'] > row['number of goals team2']:
    more_possession_wins.append(True)
  elif row['possession team2'] > row['possession team1'] and  row['number of goals team1'] < row['number of goals team2']:
    more_possession_wins.append(True)
  else:
    more_possession_wins.append(False) # Tie in possession, so doesn't apply
print(more_possession_wins)

# plotting more_possession_wins
sns.countplot(x=more_possession_wins)
plt.show()

ties = []
for index, row in data.iterrows():
  if row['number of goals team1'] == row['number of goals team2']:
    ties.append(True)
  else:
    ties.append(False)
sns.countplot(x=ties)
plt.show()
# Out:
# [True, True, True, False, False, False, False, True, False, False, True, True, False, False, True, True, False, True, False, False, False, False, False, True, False, False, False, False, False, False, True, True, True, False, True, True, False, False, True, True, False, False, False, True, False, False, False, False, False, True, True, True, False, True, False, False, False, False, False, False, False, False, False, False]

# %% [markdown]
# I realize now that a lot of the matches after the group stages went to penalty kicks which isn't accounted for in this specific variable.

# %%
# tells us if the game went to penalties
went_to_pen = []
for index, row in data.iterrows():
  if (row['number of goals team1'] == row['number of goals team2']) and 'Group' in row['category']:
    went_to_pen.append(False)
  elif row['number of goals team1'] == row['number of goals team2'] and 'Group' not in row['category']:
    went_to_pen.append(True)
  else:
    went_to_pen.append(False)

# now we can tell if the games went to penalties
print(went_to_pen)

# finding the indexes where games went to penalties
indexes_pen = [i for i, x in enumerate(went_to_pen) if x]
print(indexes_pen, '\n',  len(indexes_pen))
# Out:
# [False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False, True, False, True, True, False, False, False, False, False, True]
# [52, 54, 56, 57, 63]
#  5

# %% [markdown]
# We can confirm that this code worked because I googled how many games went to penalty kicks and the answer is 5!

# %%
# counting how many ties happened in the group stage
indexes_ties = [i for i, x in enumerate(ties) if x]
print(indexes_ties, '\n', len(indexes_ties))

# since we know 5 went to penalties that means 10 matches were ties in the group stage
# Out:
# [3, 5, 6, 8, 13, 18, 19, 27, 28, 40, 52, 54, 56, 57, 63]
#  15

# %%
# deleting group stage ties
no_ties = more_possession_wins.copy()
count = 0
for i in indexes_ties:
  if i < len(no_ties):
    del no_ties[i - count]
    count += 1
sns.countplot(x=no_ties)
plt.show()
print(count)
print(len(no_ties))
# Out:
# 11
# 53
# 49
